# %% [markdown]
# **to predict if a custtomer will repay Loan amount or not using decision tree algorithm in python**

# %%
#import the necessary packages
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
#loading the data file
Fullfilename="/content/drive/MyDrive/Decision_Tree_ Dataset.csv"
data=pd.read_csv(Fullfilename)
print(data.head())
len(data)
# Out:
#      1      2    3     4    sum Unnamed: 5
# 0  201  10018  250  3046  13515        yes
# 1  205  10016  395  3044  13660        yes
# 2  257  10129  109  3251  13746        yes
# 3  246  10064  324  3137  13771        yes
# 4  117  10115  496  3094  13822        yes
# 1000

# %%
data.shape
# Out:
# (1000, 6)

# %%
#separating the target variable
X=data.values[:,0:5]
Y=data.values[:,5]
#splitting dataset into train and test
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=100)
#Function to perform training with entropy
clf_entropy=DecisionTreeClassifier(criterion="entropy",random_state=100,max_depth=3,min_samples_leaf=5)
clf_entropy.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
#function to predict
Y_pred_en=clf_entropy.predict(X_test)
print(Y_pred_en)
# Out:
# ['yes' 'yes' 'No' 'yes' 'No' 'yes' 'No' 'No' 'No' 'No' 'No' 'No' 'yes'
#  'No' 'No' 'yes' 'yes' 'No' 'yes' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No'
#  'No' 'yes' 'No' 'No' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'No' 'No' 'yes'
#  'yes' 'yes' 'yes' 'yes' 'No' 'No' 'yes' 'No' 'yes' 'No' 'No' 'yes' 'No'
#  'yes' 'yes' 'yes' 'yes' 'No' 'No' 'No' 'yes' 'yes' 'No' 'No' 'yes' 'No'
#  'yes' 'yes' 'yes' 'No' 'yes' 'No' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No'
#  'yes' 'No' 'No' 'No' 'No' 'yes' 'No' 'yes' 'No' 'No' 'yes' 'No' 'yes'
#  'yes' 'No' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'No' 'yes' 'No'
#  'No' 'yes' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'No' 'yes' 'yes'
#  'yes' 'No' 'yes' 'No' 'No' 'yes' 'yes' 'No' 'No' 'yes' 'yes' 'No' 'No'
#  'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'No' 'yes' 'yes' 'No' 'No' 'yes' 'yes'
#  'yes' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'yes' 'No' 'No' 'No' 'No' 'yes'
#  'No' 'No' 'No' 'yes' 'No' 'No' 'yes' 'yes' 'No' 'yes' 'No' 'yes' 'No'
# ...

# %%
#checking the accuracy
print("accuracy is:",accuracy_score(Y_test,Y_pred_en)*100)
# Out:
# accuracy is: 100.0

# %%
Y_train[:5],Y_test[:5],Y_pred_en[:5]
# Out:
# (array(['yes', 'yes', 'yes', 'yes', 'No'], dtype=object),
#  array(['yes', 'yes', 'No', 'yes', 'No'], dtype=object),
#  array(['yes', 'yes', 'No', 'yes', 'No'], dtype=object))

# %%
X_test
# Out:
# array([[104, 12125, 700, 3138, 16067],
#        [351, 11140, 965, 4127, 16583],
#        [204, 13439, 191, 3720, 17554],
#        ...,
#        [432, 14306, 458, 4918, 20114],
#        [157, 10989, 830, 3803, 15779],
#        [214, 12067, 966, 3725, 16972]], dtype=object)

# %%
predicted_data=pd.DataFrame(X_test,columns=["initial_payment","Last_payment","Credit_Score","House_Number","Amount"])

# %%
predicted_data
# Out:
#     initial_payment Last_payment Credit_Score House_Number Amount
# 0               104        12125          700         3138  16067
# 1               351        11140          965         4127  16583
# 2               204        13439          191         3720  17554
# 3               276        12290          478         3923  16967
# 4               326        13167          381         3826  17700
# ..              ...          ...          ...          ...    ...
# 295             341        10058          887         4444  15730
# 296             108        14752          185         3991  19036
# 297             432        14306          458         4918  20114
# 298             157        10989          830         3803  15779
# 299             214        12067          966         3725  16972
#
# [300 rows x 5 columns]

# %%
predicted_data["Loan_will_be_payed"]=Y_pred_en
predicted_data1=predicted_data
predicted_data1
# Out:
#     initial_payment Last_payment Credit_Score House_Number Amount  \
# 0               104        12125          700         3138  16067
# 1               351        11140          965         4127  16583
# 2               204        13439          191         3720  17554
# 3               276        12290          478         3923  16967
# 4               326        13167          381         3826  17700
# ..              ...          ...          ...          ...    ...
# 295             341        10058          887         4444  15730
# 296             108        14752          185         3991  19036
# 297             432        14306          458         4918  20114
# 298             157        10989          830         3803  15779
# 299             214        12067          966         3725  16972
#
#     Loan_will_be_payed
# 0                  yes
# 1                  yes
# 2                   No
# 3                  yes
# 4                   No
# ..                 ...
# ...

# %%
# @title Loan_will_be_payed

from matplotlib import pyplot as plt
import seaborn as sns
predicted_data.groupby('Loan_will_be_payed').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Loan_will_be_payed

from matplotlib import pyplot as plt
import seaborn as sns
predicted_data.groupby('Loan_will_be_payed').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
